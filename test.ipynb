# %%
import os

# Get the current working directory (where Python was run)
current_path = os.getcwd()
print("Current working directory:", current_path)
# Out:
# Current working directory: /data2/atran16/ProteinClassification_AnhTuanTran2
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 8
#       5 print("Current working directory:", current_path)
#       7 # Get the directory of the current file
# ----> 8 current_file_dir = os.path.dirname(os.path.abspath(__file__))
#       9 print("Current file directory:", current_file_dir)
#
# NameError: name '__file__' is not defined
