# %% [markdown]
# <h1>1. Import library</h1>

# %%
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

rs_dir = "/data2/atran16/ProteinClassification_AnhTuanTran/02032026_train_v3_resultTop1/"

# %% [markdown]
# <h2>2. Line chart</h2>
# <h2>2.1 Progress of train</h2>

# %%
img_path = os.path.join(rs_dir, "train_topk_accuracy_line_chart.png")
img = mpimg.imread(img_path)

plt.figure(figsize=(20, 10))
plt.imshow(img)
plt.axis('off')  # hide axes
plt.show()

# %% [markdown]
# <h2>2.2 Progress of evaluation</h2>

# %%
img_path = os.path.join(rs_dir, "val_topk_accuracy_line_chart.png")
img = mpimg.imread(img_path)

plt.figure(figsize=(20, 10))
plt.imshow(img)
plt.axis('off')  # hide axes
plt.show()

# %% [markdown]
# <h2>2.3 Progress of TrainLoss</h2>

# %%
img_path = os.path.join(rs_dir, "train_loss_line_chart.png")
img = mpimg.imread(img_path)

plt.figure(figsize=(20, 10))
plt.imshow(img)
plt.axis('off')  # hide axes
plt.show()

# %% [markdown]
# <h2>2.4 Progress of ValLoss</h2>

# %%
img_path = os.path.join(rs_dir, "val_loss_line_chart.png")
img = mpimg.imread(img_path)

plt.figure(figsize=(20, 10))
plt.imshow(img)
plt.axis('off')  # hide axes
plt.show()

# %% [markdown]
# <h2>2.5 Progress of Epochs</h2>

# %%
img_path = os.path.join(rs_dir, "learning_rate_line_chart.png")
img = mpimg.imread(img_path)

plt.figure(figsize=(20, 10))
plt.imshow(img)
plt.axis('off')  # hide axes
plt.show()

# %% [markdown]
# <h1>3. Real protein test Report</h1>

# %%
img_path = os.path.join(rs_dir, "top20_confusion_matrix.png")
img = mpimg.imread(img_path)

plt.figure(figsize=(6, 8))
plt.imshow(img)
plt.axis('off')  # hide axes
plt.show()

# %%
import pandas as pd

# Path to the saved CSV
csv_path = "/data2/atran16/ProteinClassification_AnhTuanTran/test_train_rs/classification_report.csv"

# Read the CSV
report_df = pd.read_csv(csv_path, index_col=0)  # index_col=0 keeps class names as index

# Display the DataFrame
print(report_df)
# Out:
#               precision    recall  f1-score    support
# 2DML           0.000000  0.000000  0.000000   0.000000
# 3GB5           0.000000  0.000000  0.000000   0.000000
# 3U0Z           0.000000  0.000000  0.000000   0.000000
# 4K26           0.000000  0.000000  0.000000   0.000000
# 5GU5           0.000000  0.000000  0.000000   0.000000
# 5YQG           0.000000  0.000000  0.000000   0.000000
# 8DNM           1.000000  0.428571  0.600000   7.000000
# 8DNO           1.000000  1.000000  1.000000   5.000000
# 8DNP           1.000000  1.000000  1.000000   5.000000
# 8DNS           0.777778  0.583333  0.666667  12.000000
# 8DNU           0.000000  0.000000  0.000000   5.000000
# accuracy       0.588235  0.588235  0.588235   0.588235
# macro avg      0.343434  0.273810  0.296970  34.000000
# weighted avg   0.774510  0.588235  0.652941  34.000000

# %% [markdown]
# <h1 style="text-align: center">-------------End here!-------------</h1>
